# %% [markdown]
# # Python Sets - Practice Assignment
#
# **Topic:** Python `set` - creating a set, set methods, comparing two sets
# **Level:** Basic
# **Estimated time:** 60 - 90 minutes
# **Total questions:** 57
#
# ---
#
# ### What you need for this assignment
#
# Only what we covered in the Set session:
#
# * creating a set with `{ }`, and `set()` for an empty set
# * a set has **no duplicates** and **no order**
# * `add()`, `update()`
# * `remove()`, `discard()`, `pop()`, `clear()`, `copy()`
# * `in` and `not in`
# * `union()`, `intersection()`, `difference()`, `symmetric_difference()`
# * the symbols `|`, `&`, `-`, `^`
# * `issubset()`, `issuperset()`, `isdisjoint()`
# * `set()` and `list()` to convert between the two
# * built-in functions: `print()`, `len()`, `type()`, `id()`
#
# ### What you do NOT need
#
# You do **not** need loops, `if` conditions, functions or any library.
# Every answer can be written in a few plain lines.
#
# ### Important - about the printing order
#
# A set has **no order**. When you print a set, the items may appear in a different order
# than you typed them, and your screen may not match your friend's screen.
# **This is normal and it is not a mistake.**
#
# Where a question shows an **Expected output** with numbers, your output should match.
# Where a question uses names or words, only the **contents** matter, not the order.
#
# ### How to answer
#
# 1. Write your answer in the **empty code cell** directly below each question.
# 2. Run the cell and check your output.
# 3. Some questions ask you to run a line **on purpose to see an error**. Read the error,
#    then put a `#` in front of that line so the rest of your notebook still runs.
# 4. Do not delete the question cells.
#
# ---

# %% [markdown]
# ---
#
# ## Section A - Creating a Set
#
# A set is written with **curly** brackets `{ }`.
#
# A set has two special rules:
# 1. it **never** keeps duplicates
# 2. it has **no order**, so the items may print in a different order than you typed them

# %% [markdown]
# ### Q1. Your first set
#
# Create a set named `nums` containing `1`, `2`, `3`, `4`, `5` and print it.
#
# **Expected output**
# ```
# {1, 2, 3, 4, 5}
# ```

# %%
# Write your code here
nums={1,2,3,4,5}
print(nums)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Q2. type()
#
# Print the type of `nums`.
#
# **Expected output**
# ```
# <class 'set'>
# ```

# %%
nums = {1, 2, 3, 4, 5}
# Write your code here
print(type(nums))
# Out:
# <class 'set'>

# %% [markdown]
# ### Q3. len()
#
# Print how many items are in `nums`.
#
# **Expected output**
# ```
# 5
# ```

# %%
nums = {1, 2, 3, 4, 5}
# Write your code here
len(nums)
# Out:
# 5

# %% [markdown]
# ### Q4. A set of names
#
# Create a set named `students` with `"Riya"`, `"Amit"`, `"Karan"`.
# Print the set and its length.
#
# > The names may print in a different order than you typed them. That is normal -
# > a set has no order.

# %%
# Write your code here
students={"Riya","Amit","Karan"}
print(students)
print(len(students))
# Out:
# {'Amit', 'Riya', 'Karan'}
# 3

# %% [markdown]
# ### Q5. Duplicates disappear
#
# Create this set and print it, then print its length:
# ```python
# nums = {1, 2, 2, 3, 3, 3, 4}
# ```
#
# **Expected output**
# ```
# {1, 2, 3, 4}
# 4
# ```
# Write in a comment what happened to the repeated values.

# %%
# Write your code here
nums={1,2,2,3,3,3,4}
print(nums)
print(len(nums))
# Out:
# {1, 2, 3, 4}
# 4

# %% [markdown]
# ### Q6. The empty set trap
#
# Create `a = {}` and `b = set()`. Print the **type** of each.
#
# **Expected output**
# ```
# <class 'dict'>
# <class 'set'>
# ```
# Write in a comment how you make a truly empty set.

# %%
# Write your code here
a={}
b=set()
print(type(a))
print(type(b))
# Out:
# <class 'dict'>
# <class 'set'>

# %% [markdown]
# ### Q7. An empty set
#
# Create an empty set named `basket`. Print it, its length and its type.
#
# **Expected output**
# ```
# set()
# 0
# <class 'set'>
# ```
# Write in a comment why Python prints `set()` instead of `{}`.

# %%
# Write your code here
basket=set()
print(basket)
print(len(basket))
print(type(basket))
# Out:
# set()
# 0
# <class 'set'>

# %% [markdown]
# ### Q8. A set from a list
#
# Turn the list `[10, 20, 30, 20, 10]` into a set using `set()` and print it, then print its length.
#
# **Expected output**
# ```
# {10, 20, 30}
# 3
# ```

# %%
numbers = [10, 20, 30, 20, 10]
# Write your code here
s=set(numbers)
print(s)
print(len(s))
# Out:
# {10, 20, 30}
# 3

# %% [markdown]
# ### Q9. A mixed set
#
# Create a set with `1`, `"apple"` and `True` in it. Print it and its length.
#
# > The order will look strange - that is fine. Just check the length.

# %%
# Write your code here
mix={1,"apple",True}
print(mix)
print(len(mix))
# Out:
# {1, 'apple'}
# 2

# %% [markdown]
# ---
#
# ## Section B - A Set Has No Order and No Index

# %% [markdown]
# ### Q10. No indexing
#
# Run `print(nums[0])` and read the error.
# Then comment the line out and write in a comment what the error is called and why it happened.

# %%
nums = {1, 2, 3, 4, 5}
# Write your code here (this line WILL show an error - that is fine)
print(nums[0]) #'set' object is not subscriptable , this happens because set is unordered
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 nums = {1, 2, 3, 4, 5}
#       2 # Write your code here (this line WILL show an error - that is fine)
# ----> 3 print(nums[0])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### Q11. No slicing either
#
# Run `print(nums[0:2])`, read the error, comment it out, and write in a comment
# why slicing cannot work on a set.

# %%
nums = {1, 2, 3, 4, 5}
# Write your code here (this line WILL show an error - that is fine)
print(nums[0:2]) # bcoz set is unordered and every time there is not the same item in that index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 nums = {1, 2, 3, 4, 5}
#       2 # Write your code here (this line WILL show an error - that is fine)
# ----> 3 print(nums[0:2])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### Q12. Order does not matter
#
# Create these two sets and print whether they are equal using `==`:
# ```python
# a = {1, 2, 3}
# b = {3, 2, 1}
# ```
#
# **Expected output**
# ```
# True
# ```
# Write in a comment why they are equal even though you typed them differently.

# %%
# Write your code here
a={1,2,3}
b={3,2,1}
print(a==b) # true bcoz set is unorder when add the elements it can be prresent on any index
# Out:
# True

# %% [markdown]
# ### Q13. List vs set
#
# Compare the same values as a list and as a set:
# ```python
# list_version = [3, 1, 2, 1]
# set_version = {3, 1, 2, 1}
# ```
# Print both and both lengths. Write in a comment the two differences you can see.
#
# **Expected output**
# ```
# [3, 1, 2, 1]
# {1, 2, 3}
# 4
# 3
# ```

# %%
# Write your code here
list_version = [3, 1, 2, 1]
set_version = {3, 1, 2, 1}
print(list_version)
print(set_version)
print(len(list_version))
print(len(set_version))
# Out:
# [3, 1, 2, 1]
# {1, 2, 3}
# 4
# 3

# %% [markdown]
# ---
#
# ## Section C - Adding Items: add() and update()

# %% [markdown]
# ### Q14. add()
#
# Add `4` to the set and print it.
#
# **Expected output**
# ```
# {1, 2, 3, 4}
# ```

# %%
nums = {1, 2, 3}
# Write your code here
nums.add(4)
print(nums)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ### Q15. add() more than once
#
# Starting from an empty set `basket`, add `10`, then `20`, then `30`.
# Print the set and its length.
#
# **Expected output**
# ```
# {10, 20, 30}
# 3
# ```

# %%
basket = set()
# Write your code here
basket=set()
(basket.update([10,20,30]))
print(basket)
print(len(basket))
# Out:
# {10, 20, 30}
# 3

# %% [markdown]
# ### Q16. add() something that is already there
#
# Add `2` to the set (it is already in there) and print the set and its length.
#
# **Expected output**
# ```
# {1, 2, 3}
# 3
# ```
# Write in a comment what happened, and whether you got an error.

# %%
nums = {1, 2, 3}
# Write your code here
nums.add(2)
print(nums)
print(len(nums))
# Out:
# {1, 2, 3}
# 3

# %% [markdown]
# ### Q17. update()
#
# Add every item of `{4, 5, 6}` to `nums` in one go using `update()`, then print `nums`.
#
# **Expected output**
# ```
# {1, 2, 3, 4, 5, 6}
# ```

# %%
nums = {1, 2, 3}
# Write your code here
nums.update([4,5,6])
print(nums)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ### Q18. update() with a list
#
# `update()` also accepts a list. Add every item of `[7, 8, 8, 9]` to `nums` and print it.
#
# **Expected output**
# ```
# {1, 2, 3, 7, 8, 9}
# ```
# Write in a comment what happened to the repeated `8`.

# %%
nums = {1, 2, 3}
# Write your code here
nums.update([7,8,8,9])
print(nums)
# Out:
# {1, 2, 3, 7, 8, 9}

# %% [markdown]
# ### Q19. add() vs update()
#
# Do both and compare:
# 1. `add({4, 5})` on `first` - read the error, then comment that line out
# 2. `update({4, 5})` on `second` and print it
# 3. write **one line** in a comment explaining the difference
#
# **Expected output** (after commenting out the error line)
# ```
# {1, 2, 3, 4, 5}
# ```

# %%
first = {1, 2, 3}
second = {1, 2, 3}
# Write your code here
# first.add({4,5}) #cannot use 'set' as a set element (unhashable type: 'set') -  because in first use add which add the elemnts inside a set means like nested set
second.update({4,5}) # in update the rather than nested set its update the set
print(second)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ---
#
# ## Section D - Removing Items: remove(), discard(), pop(), clear()

# %% [markdown]
# ### Q20. remove()
#
# Remove `3` from the set and print it.
#
# **Expected output**
# ```
# {1, 2, 4, 5}
# ```

# %%
nums = {1, 2, 3, 4, 5}
# Write your code here
nums.remove(3)
print(nums)
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# ### Q21. remove() something missing
#
# Run `nums.remove(99)` and read the error.
# Comment it out and write in a comment what the error is called.

# %%
nums = {1, 2, 3}
# Write your code here (this line WILL show an error - that is fine)
nums.remove(99) #show error because there is not any 99 item in list
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 3
#       1 nums = {1, 2, 3}
#       2 # Write your code here (this line WILL show an error - that is fine)
# ----> 3 nums.remove(99)
#
# KeyError: 99

# %% [markdown]
# ### Q22. discard()
#
# Remove `3` using `discard()` and print the set.
#
# **Expected output**
# ```
# {1, 2, 4, 5}
# ```

# %%
nums = {1, 2, 3, 4, 5}
# Write your code here
nums.discard(3)
print(nums)
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# ### Q23. discard() something missing
#
# Now run `nums.discard(99)` and print the set.
#
# **Expected output**
# ```
# {1, 2, 3}
# ```
# Write in a comment how `discard()` is different from `remove()`.

# %%
nums = {1, 2, 3}
# Write your code here
nums.discard(99)
print(nums)

# discard dont show any error when element not presend in set but remove show an error
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Q24. pop()
#
# Use `pop()` to remove an item. Store what it gives back in `taken`,
# then print `taken` and the set.
#
# > A set has no order, so you cannot choose **which** item `pop()` takes.
# > Your answer may look different from your friend's - that is fine.

# %%
nums = {10, 20, 30, 40}
# Write your code here
nums.pop()
# Out:
# 40

# %% [markdown]
# ### Q25. clear()
#
# Print the set, then empty it with `clear()`, then print it and its length again.
#
# **Expected output**
# ```
# {1, 2, 3}
# set()
# 0
# ```

# %%
nums = {1, 2, 3}
# Write your code here
print(nums)
nums.clear()
print(nums)
print(len(nums))
# Out:
# {1, 2, 3}
# set()
# 0

# %% [markdown]
# ### Q26. Which one to use?
#
# In a comment, write one short line for each saying what it does:
# `add()`, `update()`, `remove()`, `discard()`, `pop()`, `clear()`.

# %%
# Write your answer as comments here
# add() - to add single item in set
# update() - add more than 1 item
# remove- remove 1 element , show an error when there not present that element
# discard - dont show any error when there is not present any number
# pop() - remove element from random position
# clear() - clear whole set

# %% [markdown]
# ---
#
# ## Section E - copy()

# %% [markdown]
# ### Q27. The `=` trap
#
# Run this and print both sets:
# ```python
# a = {1, 2, 3}
# b = a
# b.add(4)
# ```
# Was `a` changed too?
#
# **Expected output**
# ```
# {1, 2, 3, 4}
# {1, 2, 3, 4}
# ```

# %%
# Write your code here
a={1,2,3}
b=a
b.add(4)
print(a)
print(b)
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4}

# %% [markdown]
# ### Q28. Prove it with id()
#
# Create `a = {1, 2, 3}` and `b = a`, then print `id(a)` and `id(b)`.
# Write in a comment what the two numbers tell you.

# %%
# Write your code here
a={1,2,3}
b=a
b.add(4)
print(id(a))
print(id(b))
# Out:
# 1850572676608
# 1850572676608

# %% [markdown]
# ### Q29. copy()
#
# Do it properly:
# 1. make `c` a copy of `a` using `copy()`
# 2. add `99` to `c`
# 3. print `a` and `c`
#
# **Expected output**
# ```
# {1, 2, 3}
# {99, 1, 2, 3}
# ```
#
# > Look at where the `99` went. A set has no order, so a new item can appear
# > anywhere in the printout - not only at the end.

# %%
a = {1, 2, 3}
# Write your code here
c=a.copy()
c.add(99)
print(a)
print(c)
# Out:
# {1, 2, 3}
# {99, 1, 2, 3}

# %% [markdown]
# ### Q30. copy() makes a new object
#
# Make a copy of `a` and print `id(a)` and `id(c)`.
# Write in a comment whether they are the same or different, and why.

# %%
a = {1, 2, 3}
# Write your code here
c=a.copy()
c.add(99)
print(id(a)) # both are different location because c is shallow copy of a
print(id(c))
# Out:
# 1850570894112
# 1850570895904

# %% [markdown]
# ---
#
# ## Section F - Checking If Something Is In a Set

# %% [markdown]
# ### Q31. in
#
# Print whether `3` is in the set, and whether `99` is in the set.
#
# **Expected output**
# ```
# True
# False
# ```

# %%
nums = {1, 2, 3, 4, 5}
# Write your code here
print(3 in nums)
print(99 in nums)
# Out:
# True
# False

# %% [markdown]
# ### Q32. not in
#
# Print whether `99` is **not** in the set, and whether `1` is **not** in the set.
#
# **Expected output**
# ```
# True
# False
# ```

# %%
nums = {1, 2, 3, 4, 5}
# Write your code here
print(99 not in nums)
print(1 not in nums)
# Out:
# True
# False

# %% [markdown]
# ### Q33. in with names
#
# Print whether `"Riya"` is in `students`, and whether `"Zara"` is in `students`.
#
# **Expected output**
# ```
# True
# False
# ```

# %%
students = {"Riya", "Amit", "Karan"}
# Write your code here
print("Riya" in students)
print("zara" in students)
# Out:
# True
# False

# %% [markdown]
# ---
#
# ## Section G - Comparing Two Sets: the Four Big Methods
#
# Use these two sets for this whole section:
#
# ```python
# a = {1, 2, 3, 4, 5}
# b = {4, 5, 6, 7, 8}
# ```

# %% [markdown]
# ### Q34. union()
#
# Print every value that is in `a` **or** in `b`, using `union()`.
#
# **Expected output**
# ```
# {1, 2, 3, 4, 5, 6, 7, 8}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ### Q35. intersection()
#
# Print only the values that are in **both** `a` and `b`.
#
# **Expected output**
# ```
# {4, 5}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
a.intersection(b)
# Out:
# {4, 5}

# %% [markdown]
# ### Q36. difference()
#
# Print the values that are in `a` but **not** in `b`.
#
# **Expected output**
# ```
# {1, 2, 3}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
a.difference(b)
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Q37. difference() the other way round
#
# Now print the values that are in `b` but **not** in `a`.
#
# **Expected output**
# ```
# {8, 6, 7}
# ```
# Write in a comment whether `a.difference(b)` and `b.difference(a)` give the same answer.

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
b.difference(a) # no both differnce are not same
# Out:
# {6, 7, 8}

# %% [markdown]
# ### Q38. symmetric_difference()
#
# Print the values that are in `a` **or** `b` but **not in both**.
#
# **Expected output**
# ```
# {1, 2, 3, 6, 7, 8}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
a.symmetric_difference(b)
# Out:
# {1, 2, 3, 6, 7, 8}

# %% [markdown]
# ### Q39. The original sets are safe
#
# Run `a.union(b)`, then print `a` and `b`.
# Write in a comment whether these four methods change the original sets.
#
# **Expected output**
# ```
# {1, 2, 3, 4, 5}
# {4, 5, 6, 7, 8}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
a.union(b)
print(a) # these methods not changed the orignal set
print(b)
# Out:
# {1, 2, 3, 4, 5}
# {4, 5, 6, 7, 8}

# %% [markdown]
# ### Q40. Store the answer
#
# Store the union of `a` and `b` in a variable called `everything`.
# Print `everything` and its length.
#
# **Expected output**
# ```
# {1, 2, 3, 4, 5, 6, 7, 8}
# 8
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
everything= a.union(b)
print(everything)
print(len(everything))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# 8

# %% [markdown]
# ### Q41. Two class lists
#
# `monday` and `tuesday` are the students who attended on each day. Print:
# 1. everyone who came on at least one day
# 2. everyone who came on both days
# 3. everyone who came on Monday only
#
# > The names may print in any order.

# %%
monday = {"Riya", "Amit", "Karan", "Sneha"}
tuesday = {"Karan", "Sneha", "Zara"}
# Write your code here
print(monday.union(tuesday))

print(monday.intersection(tuesday))

print(monday.difference(tuesday))
# Out:
# {'Amit', 'Sneha', 'Karan', 'Zara', 'Riya'}
# {'Karan', 'Sneha'}
# {'Amit', 'Riya'}

# %% [markdown]
# ---
#
# ## Section H - The Same Four, Written as Symbols
#
# Python gives each method a short symbol:
#
# | Method | Symbol |
# |---|---|
# | `union()` | `\|` |
# | `intersection()` | `&` |
# | `difference()` | `-` |
# | `symmetric_difference()` | `^` |

# %% [markdown]
# ### Q42. Union with |
#
# Print the union of `a` and `b` using the `|` symbol.
#
# **Expected output**
# ```
# {1, 2, 3, 4, 5, 6, 7, 8}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
a|b
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ### Q43. Intersection with &
#
# Print the intersection of `a` and `b` using `&`.
#
# **Expected output**
# ```
# {4, 5}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
a&b
# Out:
# {4, 5}

# %% [markdown]
# ### Q44. Difference with -
#
# Print `a` minus `b`, and then `b` minus `a`, using the `-` symbol.
#
# **Expected output**
# ```
# {1, 2, 3}
# {8, 6, 7}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
a-b
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Q45. Symmetric difference with ^
#
# Print the symmetric difference of `a` and `b` using `^`.
#
# **Expected output**
# ```
# {1, 2, 3, 6, 7, 8}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
a^b
# Out:
# {1, 2, 3, 6, 7, 8}

# %% [markdown]
# ### Q46. Method and symbol give the same answer
#
# Print whether `a.union(b)` is equal to `a | b`, and whether
# `a.intersection(b)` is equal to `a & b`.
#
# **Expected output**
# ```
# True
# True
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
# Write your code here
print(a.union(b) == a|b)
print(a.intersection(b)==a&b)
# Out:
# True
# True

# %% [markdown]
# ---
#
# ## Section I - issubset(), issuperset(), isdisjoint()

# %% [markdown]
# ### Q47. issubset()
#
# Print whether every item of `small` is also inside `big`.
#
# **Expected output**
# ```
# True
# ```

# %%
small = {2, 3}
big = {1, 2, 3, 4, 5}
# Write your code here
small.issubset(big)
# Out:
# True

# %% [markdown]
# ### Q48. issubset() that is False
#
# Print whether `{2, 9}` is a subset of `big`, and write in a comment why.
#
# **Expected output**
# ```
# False
# ```

# %%
big = {1, 2, 3, 4, 5}
# Write your code here
{2,9}.issubset(big) # because b contains 2 but not 9
# Out:
# False

# %% [markdown]
# ### Q49. issuperset()
#
# Print whether `big` contains everything that is in `small`.
#
# **Expected output**
# ```
# True
# ```

# %%
small = {2, 3}
big = {1, 2, 3, 4, 5}
# Write your code here
big.issuperset(small)
# Out:
# True

# %% [markdown]
# ### Q50. isdisjoint()
#
# Print whether `a` and `b` have **nothing** in common, and whether `a` and `c` have
# nothing in common.
#
# **Expected output**
# ```
# False
# True
# ```

# %%
a = {1, 2, 3}
b = {3, 4, 5}
c = {7, 8, 9}
# Write your code here
print(a.isdisjoint(b))
print(b.isdisjoint(c))
# Out:
# False
# True

# %% [markdown]
# ### Q51. Course check
#
# `required` are the skills a job needs, `riya` are the skills Riya has. Print:
# 1. whether Riya has all the required skills
# 2. the required skills Riya is missing
#
# > The missing skills may print in any order.

# %%
required = {"Python", "SQL", "Excel"}
riya = {"Python", "SQL", "PowerBI"}
# Write your code here

print(riya.issuperset(required))

print(required.difference(riya))
# Out:
# False
# {'Excel'}

# %% [markdown]
# ---
#
# ## Section J - Put It All Together
#
# _3 to 6 lines each._

# %% [markdown]
# ### Q52. Remove duplicates from a list
#
# `orders` is a list with repeated items.
# 1. print the list and its length
# 2. turn it into a set called `unique_orders`
# 3. print the set and its length
#
# > The set may print in any order.

# %%
orders = ["pizza", "burger", "pizza", "pasta", "pizza", "burger"]
# Write your code here
print(orders)
print(len(orders))

unique_orders=set(orders)
print(unique_orders)
print(len(unique_orders))
# Out:
# ['pizza', 'burger', 'pizza', 'pasta', 'pizza', 'burger']
# 6
# {'burger', 'pasta', 'pizza'}
# 3

# %% [markdown]
# ### Q53. Back to a list
#
# Take `unique_orders` from the question above, turn it back into a list using `list()`,
# sort that list, and print it.
#
# **Expected output**
# ```
# ['burger', 'pasta', 'pizza']
# ```

# %%
orders = ["pizza", "burger", "pizza", "pasta", "pizza", "burger"]
# print(unique_orders)
back=list(unique_orders)
back.sort()
print(back)
# Out:
# ['burger', 'pasta', 'pizza']

# %% [markdown]
# ### Q54. Build a set step by step
#
# Do all of this in order and print the set after **every** step:
# 1. start with an empty set called `skills`
# 2. add `"Python"`
# 3. add `"SQL"`
# 4. add `"Python"` again
# 5. update it with `["Excel", "PowerBI"]`
# 6. discard `"PowerBI"`
# 7. finally print the length
#
# > The order will look random. Only the contents matter.

# %%
# Write your code here
skills=set()
skills.add("python")
skills.add("SQL")
skills.add("python")
skills.update(["excel","Power_BI"])
print(skills)
skills.discard("Power_BI")
print(skills)
print(len(skills))
# Out:
# {'SQL', 'excel', 'Power_BI', 'python'}
# {'SQL', 'excel', 'python'}
# 3

# %% [markdown]
# ### Q55. Two shops
#
# `shop_a` and `shop_b` are the items each shop sells. Print:
# 1. every item you can buy anywhere
# 2. items both shops sell
# 3. items only shop A sells
# 4. items sold by only one of the two shops
# 5. how many different items there are in total

# %%
shop_a = {"milk", "bread", "eggs", "rice"}
shop_b = {"eggs", "rice", "oil", "sugar"}
# Write your code here
shop_a.union(shop_b)
shop_a.intersection(shop_b)
shop_a.difference(shop_b)
shop_a.symmetric_difference(shop_b)
# Out:
# {'bread', 'milk', 'oil', 'sugar'}

# %% [markdown]
# ### Q56. Exam attendance
#
# `exam1` and `exam2` are the students who attended each exam. Print:
# 1. how many students attended exam 1
# 2. students who attended both exams
# 3. students who missed exam 2
# 4. whether anyone attended both (`True` or `False` using `isdisjoint`)

# %%
exam1 = {"Riya", "Amit", "Karan", "Sneha"}
exam2 = {"Karan", "Sneha", "Zara"}
# Write your code here
print(len(exam1))
print(exam1.intersection(exam2))
print(exam1-exam2)
print(exam1.isdisjoint(exam2))
# Out:
# 4
# {'Karan', 'Sneha'}
# {'Amit', 'Riya'}
# False

# %% [markdown]
# ### Q57. List, tuple or set?
#
# In a comment, write which one you would use for each and why (one line each):
# 1. the marks of one student, in subject order
# 2. the different cities your customers come from
# 3. the fixed pair of latitude and longitude of a shop
# 4. the tags on a blog post, where each tag must appear only once

# %%
# Write your answer as comments here
# 1 -> list ( marks is order and can change)
# 2 -> set (different cities means unique)
# 3 -> tuple ( for fixed value )
# 4 -> set ( tag appear only once )

# %% [markdown]
# ---
#
# ## Finished?
#
# 1. Run **Kernel -> Restart & Run All** and make sure every cell runs top to bottom without errors.
# 2. Rename the file to `YourName_AssignmentX.ipynb`.
# 3. Submit the `.ipynb` file.
#
# **Do not delete the question cells** — your answers must stay under the matching question.
