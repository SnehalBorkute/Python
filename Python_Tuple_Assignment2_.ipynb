# %% [markdown]
# # Python Tuples - Practice Assignment
#
# **Topic:** Python `tuple` - creating, indexing, slicing, the two tuple methods
# **Level:** Basic
# **Estimated time:** 60 - 90 minutes
# **Total questions:** 54
#
# ---
#
# ### What you need for this assignment
#
# Only what we covered in the Tuple session:
#
# * creating a tuple with `( )`, and the one-item comma rule `("apple",)`
# * index numbers and negative index numbers
# * slicing `tuple[start:stop]`
# * a tuple **cannot be changed** (immutable)
# * the two tuple methods: `count()` and `index()`
# * `+` to join tuples and `*` to repeat a tuple
# * packing and unpacking
# * `list()` and `tuple()` to convert between the two
# * built-in functions: `print()`, `len()`, `type()`, `id()`
#
# ### What you do NOT need
#
# You do **not** need loops, `if` conditions, functions or any library.
# Every answer can be written in a few plain lines.
#
# ### How to answer
#
# 1. Write your answer in the **empty code cell** directly below each question.
# 2. Run the cell and check your output.
# 3. Where the question shows an **Expected output**, your output must look exactly the same.
# 4. Some questions ask you to run a line **on purpose to see an error**. Read the error,
#    then put a `#` in front of that line so the rest of your notebook still runs.
# 5. Do not delete the question cells.
#
# > **Remember:** a tuple is just a list that can never be changed. Everything you learned
# > about indexing and slicing works exactly the same way.
#
# ---

# %% [markdown]
# ---
#
# ## Section A - Creating a Tuple
#
# _A tuple is written with **round** brackets `( )`._

# %% [markdown]
# ### Q1. Your first tuple
#
# Create a tuple named `fruits` with these items in this order:
# `"apple"`, `"banana"`, `"cherry"`, `"mango"`.
# Print it.
#
# **Expected output**
# ```
# ('apple', 'banana', 'cherry', 'mango')
# ```

# %%
# Write your code here
fruits=('apple','banana','cherry','mango')
print(fruits)
# Out:
# ('apple', 'banana', 'cherry', 'mango')

# %% [markdown]
# ### Q2. type()
#
# Print the type of `fruits`.
#
# **Expected output**
# ```
# <class 'tuple'>
# ```

# %%
fruits = ("apple", "banana", "cherry", "mango")
# Write your code here
print(type(fruits))
# Out:
# <class 'tuple'>

# %% [markdown]
# ### Q3. len()
#
# Print how many items `fruits` has.
#
# **Expected output**
# ```
# 4
# ```

# %%
fruits = ("apple", "banana", "cherry", "mango")
# Write your code here
len(fruits)
# Out:
# 4

# %% [markdown]
# ### Q4. A tuple of numbers
#
# Create a tuple named `marks` with `78`, `85`, `92`, `61`, `74`.
# Print the tuple, its length and its type.

# %%
# Write your code here
marks=( '78','85','92','61','74')
print(marks)
print(type(marks))
print(len(marks))
# Out:
# ('78', '85', '92', '61', '74')
# <class 'tuple'>
# 5

# %% [markdown]
# ### Q5. A mixed tuple
#
# Create a tuple named `info` with your name (text), your age (number) and `True`.
# Print the tuple, then print the type of the first item and the type of the second item.
#
# **Expected output (sample)**
# ```
# ('Amar', 25, True)
# <class 'str'>
# <class 'int'>
# ```

# %%
# Write your code here
info=('snehal',22,True)
print(info)
print(type('snehal'))
print(type(22))
# Out:
# ('snehal', 22, True)
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### Q6. An empty tuple
#
# Create an empty tuple named `empty`.
# Print it, its length and its type.
#
# **Expected output**
# ```
# ()
# 0
# <class 'tuple'>
# ```

# %%
# Write your code here
a=()
print(a)
print(len(a))
print(type(a))
# Out:
# ()
# 0
# <class 'tuple'>

# %% [markdown]
# ### Q7. A tuple with ONE item - the trap
#
# Create these two and print the **type** of each:
# ```python
# one = ("apple")
# two = ("apple",)
# ```
# Write in a comment which one is really a tuple and why.
#
# **Expected output**
# ```
# <class 'str'>
# <class 'tuple'>
# ```

# %%
# Write your code here
one = ("apple")
two = ("apple",)
print(type(one))
print(type(two))
# Out:
# <class 'str'>
# <class 'tuple'>

# %% [markdown]
# ### Q8. A tuple without brackets
#
# Python lets you skip the brackets. Create `point = 10, 20, 30` and print it and its type.
#
# **Expected output**
# ```
# (10, 20, 30)
# <class 'tuple'>
# ```

# %%
# Write your code here
point=10,20,20
print(point)
print(type(point))
# Out:
# (10, 20, 20)
# <class 'tuple'>

# %% [markdown]
# ### Q9. A tuple inside a tuple
#
# Create this tuple exactly:
# ```python
# student = ("Riya", 21, ("Python", "SQL", "Excel"))
# ```
# Print the tuple and its length.
#
# **Expected output**
# ```
# ('Riya', 21, ('Python', 'SQL', 'Excel'))
# 3
# ```
# Write in a comment why the length is 3 and not 5.

# %%
# Write your code here
student = ("Riya", 21, ("Python", "SQL", "Excel"))
print(len(student))
# 3 because it is actual student tuple length not 5 because it is nested list
# Out:
# 3

# %% [markdown]
# ### Q10. id()
#
# Create `a = (1, 2, 3)` and print `a` and `id(a)`.
# (Your id number will be different from your friend's - that is normal.)

# %%
# Write your code here
a=(1,2,3)
print(f"the value of a is {a} and id of a is {id(a)}")
# Out:
# the value of a is (1, 2, 3) and id of a is 1900230085264

# %% [markdown]
# ---
#
# ## Section B - Indexing a Tuple
#
# _Exactly the same as a list. Counting starts at **0**, and `-1` is the last item._

# %% [markdown]
# ### Q11. First and last
#
# Print the first city and the last city using index numbers.
#
# **Expected output**
# ```
# Delhi
# Jaipur
# ```

# %%
cities = ("Delhi", "Mumbai", "Pune", "Chennai", "Kolkata", "Jaipur")
# Write your code here
print(cities[0])
print(cities[-1])
# Out:
# Delhi
# Jaipur

# %% [markdown]
# ### Q12. Middle items
#
# Print the 3rd city and the 4th city.
#
# **Expected output**
# ```
# Pune
# Chennai
# ```

# %%
cities = ("Delhi", "Mumbai", "Pune", "Chennai", "Kolkata", "Jaipur")
# Write your code here
print(cities[2])
print(cities[3])
# Out:
# Pune
# Chennai

# %% [markdown]
# ### Q13. Negative indexing
#
# Print the last and second-last city using negative index numbers.
#
# **Expected output**
# ```
# Jaipur
# Kolkata
# ```

# %%
cities = ("Delhi", "Mumbai", "Pune", "Chennai", "Kolkata", "Jaipur")
# Write your code here
print(cities[-1])
print(cities[-2])
# Out:
# Jaipur
# Kolkata

# %% [markdown]
# ### Q14. From the inner tuple
#
# From `student` print:
# 1. the name
# 2. the whole skills tuple
# 3. only `"SQL"`
#
# **Expected output**
# ```
# Riya
# ('Python', 'SQL', 'Excel')
# SQL
# ```

# %%
student = ("Riya", 21, ("Python", "SQL", "Excel"))
# Write your code here
print(student[0])
print(student[2])
print(student[2][1])
# Out:
# Riya
# ('Python', 'SQL', 'Excel')
# SQL

# %% [markdown]
# ### Q15. Add two items
#
# Print the total of the first and the last mark.
#
# **Expected output**
# ```
# 152
# ```

# %%
marks = (78, 85, 92, 61, 74)
# Write your code here
print(marks[0]+marks[-1])
# Out:
# 152

# %% [markdown]
# ### Q16. Index out of range
#
# Run `print(cities[10])` and read the error.
# Then comment the line out and write in a comment what the error is called and why it happened.

# %%
cities = ("Delhi", "Mumbai", "Pune")
# Write your code here (this line WILL show an error - that is fine)
print(cities[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 cities = ("Delhi", "Mumbai", "Pune")
#       2 # Write your code here (this line WILL show an error - that is fine)
# ----> 3 print(cities[10])
#
# IndexError: tuple index out of range

# %% [markdown]
# ---
#
# ## Section C - Slicing a Tuple
#
# _`tuple[start:stop]` gives items from `start` up to **but not including** `stop`. The result is a new tuple._

# %% [markdown]
# ### Q17. First three
#
# Print the first three numbers.
#
# **Expected output**
# ```
# (10, 20, 30)
# ```

# %%
nums = (10, 20, 30, 40, 50, 60, 70, 80)
# Write your code here
print(nums[0:3])
# Out:
# (10, 20, 30)

# %% [markdown]
# ### Q18. Last three
#
# Print the last three numbers.
#
# **Expected output**
# ```
# (60, 70, 80)
# ```

# %%
nums = (10, 20, 30, 40, 50, 60, 70, 80)
# Write your code here
print(nums[5:])
# Out:
# (60, 70, 80)

# %% [markdown]
# ### Q19. Middle part
#
# Print items from index 2 up to (not including) index 6.
#
# **Expected output**
# ```
# (30, 40, 50, 60)
# ```

# %%
nums = (10, 20, 30, 40, 50, 60, 70, 80)
# Write your code here
print(nums[2:6])
# Out:
# (30, 40, 50, 60)

# %% [markdown]
# ### Q20. Every second item
#
# Print every second item using a step.
#
# **Expected output**
# ```
# (10, 30, 50, 70)
# ```

# %%
nums = (10, 20, 30, 40, 50, 60, 70, 80)
# Write your code here
print(nums[0:7:2])
# Out:
# (10, 30, 50, 70)

# %% [markdown]
# ### Q21. Backwards
#
# Print the whole tuple in reverse order using a slice.
#
# **Expected output**
# ```
# (80, 70, 60, 50, 40, 30, 20, 10)
# ```

# %%
nums = (10, 20, 30, 40, 50, 60, 70, 80)
# Write your code here
print(nums[::-1])
# Out:
# (80, 70, 60, 50, 40, 30, 20, 10)

# %% [markdown]
# ### Q22. A slice is a new tuple
#
# Take a slice of `nums`, print it, print its type, then print `nums` again.
# Write in a comment whether the original tuple changed.

# %%
nums = (10, 20, 30, 40, 50)
# Write your code here
print(nums[0:2])
print(type(nums[0:2]))
print(nums) # no , orignal tuple not chnaged
# Out:
# (10, 20)
# <class 'tuple'>
# (10, 20, 30, 40, 50)

# %% [markdown]
# ---
#
# ## Section D - A Tuple Cannot Be Changed
#
# _This is the one big difference from a list. A tuple is **immutable**._

# %% [markdown]
# ### Q23. Try to change an item
#
# Run this line and read the error:
# ```python
# fruits[0] = "grapes"
# ```
# Then comment it out and write in a comment what the error is called.

# %%
fruits = ("apple", "banana", "cherry")
# Write your code here (this line WILL show an error - that is fine)
fruits[0]="grapes"  # 'tuple' object does not support item assignment because it is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 fruits = ("apple", "banana", "cherry")
#       2 # Write your code here (this line WILL show an error - that is fine)
# ----> 3 fruits[0]="grapes"  # 'tuple' object does not support item assignment because it is immutable
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Q24. There is no append()
#
# Run `fruits.append("grapes")` and read the error.
# Then comment it out and write in a comment why a tuple has no `append()`.

# %%
fruits = ("apple", "banana", "cherry")
# Write your code here (this line WILL sho w an error - that is fine)
fruits.append("grapes") # tuple has no append() beacuse it is immutable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 3
#       1 fruits = ("apple", "banana", "cherry")
#       2 # Write your code here (this line WILL show an error - that is fine)
# ----> 3 fruits.append("grapes")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ### Q25. There is no remove() either
#
# Run `fruits.remove("apple")`, read the error, comment it out,
# then write in a comment which other list methods a tuple also does **not** have.

# %%
fruits = ("apple", "banana", "cherry")
# Write your code here (this line WILL show an error - that is fine)
fruits.remove("apple") #append,extend,insert,remove,pop
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 3
#       1 fruits = ("apple", "banana", "cherry")
#       2 # Write your code here (this line WILL show an error - that is fine)
# ----> 3 fruits.remove("apple")
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %% [markdown]
# ### Q26. How many methods does a tuple have?
#
# In a comment, list every method a tuple has.
# (Hint: there are only two.)

# %%
# Write your answer as a comment here
# count
#index

# %% [markdown]
# ### Q27. The list inside a tuple
#
# Something surprising. Run this:
# ```python
# mixed = (1, 2, ["a", "b"])
# mixed[2].append("c")
# print(mixed)
# ```
# Print the result and write in a comment why this worked even though tuples cannot change.
#
# **Expected output**
# ```
# (1, 2, ['a', 'b', 'c'])
# ```

# %%
# Write your code here
mixed = (1, 2, ["a", "b"])
mixed[2].append("c")
print(mixed) # because mixed[2] in list
# Out:
# (1, 2, ['a', 'b', 'c'])

# %% [markdown]
# ### Q28. Why use a tuple at all?
#
# In a comment, write two reasons to use a tuple instead of a list.

# %%
# Write your answer as comments here
# 1. tuple is fast than list
# 2.tuple contains less memory
#use for static data

# %% [markdown]
# ---
#
# ## Section E - The Two Tuple Methods: count() and index()

# %% [markdown]
# ### Q29. count()
#
# Print how many times `3` appears.
#
# **Expected output**
# ```
# 4
# ```

# %%
nums = (1, 3, 5, 3, 7, 3, 2, 3)
# Write your code here
nums.count(3)
# Out:
# 4

# %% [markdown]
# ### Q30. count() of something missing
#
# Print how many times `9` appears in the same tuple.
#
# **Expected output**
# ```
# 0
# ```

# %%
nums = (1, 3, 5, 3, 7, 3, 2, 3)
# Write your code here
nums.count(9)
# Out:
# 0

# %% [markdown]
# ### Q31. index()
#
# Print the position of `"Chennai"`.
#
# **Expected output**
# ```
# 3
# ```

# %%
cities = ("Delhi", "Mumbai", "Pune", "Chennai", "Kolkata")
# Write your code here
cities.index("Chennai")
# Out:
# 3

# %% [markdown]
# ### Q32. index() with a repeated value
#
# Print the position of `"banana"` and write in a comment which of the two it gives you.
#
# **Expected output**
# ```
# 1
# ```

# %%
fruits = ("apple", "banana", "cherry", "banana")
# Write your code here
fruits.index("banana")
# Out:
# 1

# %% [markdown]
# ### Q33. index() of something missing
#
# Run `fruits.index("grapes")`, read the error, then comment it out and write in a comment
# what the error is called and why `count("grapes")` does not give an error.

# %%
fruits = ("apple", "banana", "cherry")
# Write your code here (this line WILL show an error - that is fine)
print(fruits.index("grapes")) #ValueError: tuple.index(x): x not in tuple => error says there is no index for that value count is 0 when not element there but index give error when not find the index of that perticular item
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 3
#       1 fruits = ("apple", "banana", "cherry")
#       2 # Write your code here (this line WILL show an error - that is fine)
# ----> 3 print(fruits.index("grapes"))
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# ### Q34. Both methods together
#
# For the `orders` tuple print:
# 1. how many times `"pizza"` was ordered
# 2. the position of the first `"pizza"`
# 3. the position of `"pasta"`

# %%
orders = ("burger", "pizza", "pasta", "pizza", "salad", "pizza")
# Write your code here
print(orders.count("pizza"))
print(orders.index("pizza"))
print(orders.index("pasta"))
# Out:
# 3
# 1
# 2

# %% [markdown]
# ---
#
# ## Section F - Joining and Repeating

# %% [markdown]
# ### Q35. Joining with +
#
# Join `a` and `b` into a new tuple called `joined` and print it.
# Then print `a` to show it did not change.
#
# **Expected output**
# ```
# (1, 2, 3, 4, 5)
# (1, 2, 3)
# ```

# %%
a = (1, 2, 3)
b = (4, 5)
# Write your code here
joined=a+b
print(joined)
print(a)
# Out:
# (1, 2, 3, 4, 5)
# (1, 2, 3)

# %% [markdown]
# ### Q36. Repeating with *
#
# 1. Print a tuple containing `"ha"` three times.
# 2. Print a tuple of five zeros.
#
# **Expected output**
# ```
# ('ha', 'ha', 'ha')
# (0, 0, 0, 0, 0)
# ```

# %%
# Write your code here
print(('ha',)*3)
print((0,)*5)
# Out:
# ('ha', 'ha', 'ha')
# (0, 0, 0, 0, 0)

# %% [markdown]
# ### Q37. The comma matters here too
#
# Print `("ha") * 3` and `("ha",) * 3` and compare.
# Write in a comment why they are different.
#
# **Expected output**
# ```
# hahaha
# ('ha', 'ha', 'ha')
# ```

# %%
# Write your code here
print(("ha")*3) # this is considered string
print(("ha",)*3) # this consider  tuple
# Out:
# hahaha
# ('ha', 'ha', 'ha')

# %% [markdown]
# ### Q38. Growing a tuple
#
# A tuple cannot be changed, but you can build a new one.
# Add `"grapes"` to the end of `fruits` by making a new tuple, and print it.
#
# **Expected output**
# ```
# ('apple', 'banana', 'grapes')
# ```

# %%
fruits = ("apple", "banana")
# Write your code here
a=list(fruits)
a.append("grapes")
# print(a)
tuple(a)
# Out:
# ('apple', 'banana', 'grapes')

# %% [markdown]
# ---
#
# ## Section G - Packing and Unpacking
#
# _Putting values into a tuple is **packing**. Taking them back out into names is **unpacking**._

# %% [markdown]
# ### Q39. Packing
#
# Pack the three values `"Riya"`, `21`, `"Pune"` into a tuple named `student`
# **without** using brackets. Print it.
#
# **Expected output**
# ```
# ('Riya', 21, 'Pune')
# ```

# %%
# Write your code here
student=('Riya', 21, 'Pune')
print(student)
# Out:
# ('Riya', 21, 'Pune')

# %% [markdown]
# ### Q40. Unpacking
#
# Unpack `student` into three names `name`, `age`, `city` in one line.
# Print each one on its own line.
#
# **Expected output**
# ```
# Riya
# 21
# Pune
# ```

# %%
student = ("Riya", 21, "Pune")
# Write your code here
x,y,z=student
print(x)
print(y)
print(z)
# Out:
# Riya
# 21
# Pune

# %% [markdown]
# ### Q41. Too few names
#
# Run `name, age = student` and read the error.
# Comment it out and write in a comment what the rule is.

# %%
student = ("Riya", 21, "Pune")
# Write your code here (this line WILL show an error - that is fine)
x,y=student #ValueError: too many values to unpack the rule is rest of the element stores in tuple use *c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 3
#       1 student = ("Riya", 21, "Pune")
#       2 # Write your code here (this line WILL show an error - that is fine)
# ----> 3 x,y=student
#
# ValueError: too many values to unpack (expected 2, got 3)

# %% [markdown]
# ### Q42. Swapping with a tuple
#
# Swap the values of `x` and `y` in one line using tuple packing/unpacking, then print both.
#
# **Expected output**
# ```
# 20
# 10
# ```

# %%
x = 10
y = 20
# Write your code here
num=x
# Out:
# 10

# %% [markdown]
# ### Q43. Unpack a nested tuple
#
# Unpack `record` into `name`, `age` and `skills`, then print the second skill.
#
# **Expected output**
# ```
# Riya
# 21
# SQL
# ```

# %%
record = ("Riya", 21, ("Python", "SQL", "Excel"))
# Write your code here
name,age,skill=record
print(name)
print(age)
print(skill[1])
# Out:
# Riya
# 21
# SQL

# %% [markdown]
# ---
#
# ## Section H - Tuple and List Together
#
# _`list()` turns something into a list, `tuple()` turns something into a tuple._

# %% [markdown]
# ### Q44. Tuple to list
#
# Convert `fruits` into a list called `fruits_list`. Print it and its type.
#
# **Expected output**
# ```
# ['apple', 'banana', 'cherry']
# <class 'list'>
# ```

# %%
fruits = ("apple", "banana", "cherry")
# Write your code here
fruit_list=list(fruits)
print(fruit_list)
print(type(fruit_list))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %% [markdown]
# ### Q45. List to tuple
#
# Convert the list `colors` into a tuple. Print it and its type.
#
# **Expected output**
# ```
# ('red', 'green', 'blue')
# <class 'tuple'>
# ```

# %%
colors = ["red", "green", "blue"]
# Write your code here
a=tuple(colors)
print(a)
print(type(a))
# Out:
# ('red', 'green', 'blue')
# <class 'tuple'>

# %% [markdown]
# ### Q46. Change a tuple the long way
#
# A tuple cannot be changed - but you can convert, change, and convert back.
# Change `"banana"` to `"grapes"` in `fruits` using this trick, and print the final tuple.
#
# **Expected output**
# ```
# ('apple', 'grapes', 'cherry')
# ```

# %%
fruits = ("apple", "banana", "cherry")
# Write your code here
a=list(fruits)
a[1]="banana"

tuple(a)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# ### Q47. Sort a tuple the long way
#
# A tuple has no `sort()`. Sort the marks by converting to a list, sorting, and converting back.
# Print the sorted tuple.
#
# **Expected output**
# ```
# (33, 45, 56, 78, 91)
# ```

# %%
marks = (56, 91, 33, 78, 45)
# Write your code here
m=list(marks)
m.sort()
tuple(m)
# Out:
# (33, 45, 56, 78, 91)

# %% [markdown]
# ### Q48. A tuple from a string
#
# Convert the word `"PYTHON"` into a tuple of letters and print it, then print its length.
#
# **Expected output**
# ```
# ('P', 'Y', 'T', 'H', 'O', 'N')
# 6
# ```

# %%
word = "PYTHON"
# Write your code here

tuple(word)
# Out:
# ('P', 'Y', 'T', 'H', 'O', 'N')

# %% [markdown]
# ---
#
# ## Section I - Put It All Together
#
# _3 to 6 lines each. Only what you learned above._

# %% [markdown]
# ### Q49. Tuple report
#
# Using the `orders` tuple, print each of these on its own line:
# 1. the total number of orders
# 2. how many times `"pizza"` was ordered
# 3. the position of the first `"pasta"`
# 4. the first three orders
# 5. the last order

# %%
orders = ("pizza", "burger", "pizza", "pasta", "pizza", "burger", "salad")
# Write your code here
print(len(orders))
print(orders.count("pizza"))
print(orders.index("pasta"))
print(orders[0:3])
print(orders[-1])
# Out:
# 7
# 3
# 3
# ('pizza', 'burger', 'pizza')
# salad

# %% [markdown]
# ### Q50. Fix the wrong tuple
#
# `"Kolkta"` is spelled wrong and `"Goa"` should not be in the tuple.
# Using the convert-change-convert-back trick:
# 1. correct the spelling
# 2. remove `"Goa"`
# 3. add `"Jaipur"` at the end
# 4. print the final tuple and its type
#
# **Expected output**
# ```
# ('Delhi', 'Mumbai', 'Kolkata', 'Chennai', 'Jaipur')
# <class 'tuple'>
# ```

# %%
cities = ("Delhi", "Mumbai", "Kolkta", "Goa", "Chennai")
# Write your code here
city=list(cities)
city[2]="Kolkata"
city.remove("Goa")
city.append("jaipur")
final=tuple(city)
print(final)
print(type(final))
# Out:
# ('Delhi', 'Mumbai', 'Kolkata', 'Chennai', 'jaipur')
# <class 'tuple'>

# %% [markdown]
# ### Q51. Highest and lowest mark
#
# Without using `max()` or `min()`:
# 1. sort the marks using the convert trick
# 2. print the lowest mark
# 3. print the highest mark
# 4. print the top three marks
#
# **Expected output**
# ```
# 33
# 95
# (95, 91, 78)
# ```

# %%
marks = (56, 91, 33, 78, 45, 95)
# Write your code here
m=list(marks)
m.sort()
print(m)
print(m[0])
print(m[-1])
m.reverse()
# print(marks.index(95))
print(m[:3])
# Out:
# [33, 45, 56, 78, 91, 95]
# 33
# 95
# [95, 91, 78]

# %% [markdown]
# ### Q52. Student record
#
# `record` holds a name, an age and a tuple of marks.
# 1. unpack it into `name`, `age`, `marks`
# 2. print the name and the age
# 3. print how many subjects there are
# 4. print the first mark and the last mark
# 5. print the total of the first two marks

# %%
record = ("Riya", 21, (78, 85, 92, 61))
# Write your code here
name,age,marks=record
print(name)
print(age)
print(len(marks))
print(marks[0])
print(marks[-1])
print(marks[1]+marks[0])
# Out:
# Riya
# 21
# 4
# 78
# 61
# 163

# %% [markdown]
# ### Q53. Two tuples
#
# `morning` and `evening` are two batches of students.
# 1. join them into one tuple called `all_students` and print it
# 2. print how many students there are in total
# 3. print the first and the last student
# 4. print how many times `"Riya"` appears

# %%
morning = ("Riya", "Amit", "Zara")
evening = ("Karan", "Sneha", "Riya")
# Write your code here
all_students =morning+evening
print(all_students)
print(len(all_students))
print(all_students[0],all_students[1])
print(all_students.count("Riya"))
# Out:
# ('Riya', 'Amit', 'Zara', 'Karan', 'Sneha', 'Riya')
# 6
# Riya Amit
# 2

# %% [markdown]
# ### Q54. List or tuple?
#
# In a comment, write which one you would use for each of these and why (one line each):
# 1. the twelve months of the year
# 2. a shopping list you keep adding to
# 3. the latitude and longitude of a place
# 4. the names of students present in class today

# %%
# Write your answer as comments here
# tuple => bcoz month of year is fixed
# list=>  shopping list can change
# tuple=> longitute and latitude is fix of a place
# tuple=> because todays attendence is fixed for

# %% [markdown]
# ---
#
# ## Finished?
#
# 1. Run **Kernel -> Restart & Run All** and make sure every cell runs top to bottom without errors.
# 2. Rename the file to `YourName_AssignmentX.ipynb`.
# 3. Submit the `.ipynb` file.
#
# **Do not delete the question cells** — your answers must stay under the matching question.
