# %%
import pywintypes
import win32com.client

print("successful")
# Out:
# successful

# %%
import win32com.client

speaker = win32com.client.Dispatch("SAPI.SpVoice")
speaker.Speak("Hello Snehal, your voice assistant is working!")
l=["shruti","shweta","snehal"]
for name in l:
    message=f"Shotout to {name}"
    speaker.speak(message)
    print(message)
    

print("Voice successful")
# Out:
# Shotout to shruti
# Shotout to shweta
# Shotout to snehal
# Voice successful
